# %% [markdown]
# #### *Run this cell to resolve import issues*

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../landis/backend/'))
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path)
# Out:
# c:\Users\hengj\Dropbox\My PC (LAPTOP-3RC4T7KN)\Desktop\500\capstone-landis\landis\backend

# %% [markdown]
# ## Please Ignore All The Comments

# %%
# %matplotlib inline
from log_parser import parse_keyboard_log
from log_parser import extract_predefined_patterns
from log_parser import parse_mouse_log
from keyboard_heatmap import KeyboardHeatmap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from log_parser import parse_keyboard_log
from numpy_ringbuffer import RingBuffer

sample_size = 40
labels = ['HEN', 'ZIR', 'JOS', 'MAR', 'MIT'] # Left out Jon bc he has no SOL logfile
# Also I should just change this to use the routing file but it is what it is

# Creates 4 subplots
fig, ax = plt.subplots(1, 2, figsize=(40, 20))

predefined_patterns = {'w':['s','q','1'], 's':['w'], 'd':['f'], 'f':['d'], 'q':['a','w'], 'a':['q'], '1':['w']}
for name in labels: # For each name listed above:

    # Convert the logfile to a DataFrame
    kb = parse_keyboard_log(f"../logs/{name}/SOL/key.log")


    # Temperory dictionaries used to stire the most recent press or release for keys in the predefined_patterns
    tempPressDict = {}
    tempReleaseDict = {}
    # The result dictionary used to store the average/highest/shortest duration for the key release-press pairs in the predefined_patterns
    # The result should have the following format:  'resultKey':[totalDuration, freq, longestDuration, shortestDuration, averageDuration]
    durations_dict = {}
    duration_data = {}
    #Find the key release-press pairs and calculate duration and freq for each pair, and re
    for _, row in kb.iterrows():
        # Extract keyname (remove surrounding '' if needed)
        key = row['key']
        key = key.replace("'", "")

        if key in predefined_patterns:
            # Get the time and the action for this row
            time = float(row['time'])
            action = row['action']

            if action == 'pressed': # if it is the press of a release-press pair
                # Update the time in tempPressDict
                tempPressDict[key] = time
                # Check for the release-press pair
                for pairedKey in predefined_patterns[key]:# check release-press pair for all paired keys for this key
                    if pairedKey in tempReleaseDict:# if we have the data for the required key release 
                        # Validate a release-press pair by 2 metrics: 1. press time < release time. 2. (press time - release time) < 0.3 second
                        if tempReleaseDict[pairedKey] < time and time - tempReleaseDict[pairedKey] <= 0.3:
                            curr_duration = time - tempReleaseDict[pairedKey]# calculate duration for this release-press pair
                            resultKey = key + pairedKey # compute resultKey
                            if resultKey in durations_dict:# if it's not the first record for resultKey
                                # update total duration and freq
                                durations_dict[resultKey].append(curr_duration)
                                durations_np = np.array(durations_dict[resultKey]) # Convert to numpy array
                                if durations_np.size > 3:
                                    duration_data[resultKey][0].append((durations_np.mean(), durations_np.std()))
                                    duration_data[resultKey][1].append('Hengjun')
                            else:# if it is the first record for resultKey
                                durations_dict[resultKey] = RingBuffer(capacity=sample_size, dtype=float)
                                duration_data[resultKey] = [[], []]
            else: # if it is the release of a release-press pair
                tempReleaseDict[key] = time # Update the time in tempReleaseDict

    # I got pretty lazy here but it works lol
    color = 'black'
    if name == 'HEN':
        color = 'tab:blue'
    if name == 'ZIR':
        color = 'tab:red'
    if name == 'JOS':
        color = 'tab:olive'
    if name == 'MAR':
        color = 'tab:green'
    if name == 'MIT':
        color = 'tab:orange'
    if name == 'JON':
        color = 'tab:purple'

    # Each call to scatter() on the same axes just draws more points on top of it
    ax[0].set_title('ws')
    ax[0].set_xlim(0.075, 0.25)
    ax[0].set_ylim(0.00, 0.09)
    ax[0].scatter([x for x, _ in duration_data['ws'][0]], [y for _, y in duration_data['ws'][0]], c=color, alpha=0.5)

    ax[1].set_title('sw')
    ax[1].set_xlim(0.075, 0.25)
    ax[1].set_ylim(0.00, 0.09)
    ax[1].scatter([x for x, _ in duration_data['sw'][0]], [y for _, y in duration_data['sw'][0]], c=color, alpha=0.5)

# %%
from log_parser import parse_keyboard_log
from log_parser import parse_mouse_log
from keyboard_heatmap import KeyboardHeatmap
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler


# Set to false to test non-binary classification
test_binary = False

# Set to false for regular sampling
undersampling = False
oversampling = True

# List of parsed logfiles
keyboard = []
mouse = []

# Read logfile paths from .routing
with open("../.routing", 'r', encoding='utf-8') as f:
    log_paths = f.read().splitlines()   # Read lines without '\n's
    for path in log_paths:
        if 'key' in path:
            keyboard.append(parse_keyboard_log('../' + path))
        elif 'mouse' in path:
            mouse.append(parse_mouse_log('../' + path))

seg_length = 60
# The quintessential target class
target = "MAR"

# Empty lists for inserting data
X_actual = []
Y_actual = []

# For confusion matrix plotting
labels = []

for k in range(len(keyboard)):
    l = None
    for i in range(int(keyboard[k].time.iloc[-1] / seg_length)):
        # For each segment in each logfile
        # Create a heatmap for that segment
        heatmap = KeyboardHeatmap(keyboard[k], i, seg_length)
        if test_binary: heatmap = heatmap.to_binary_class_label(target)
        # If the heatmap isn't blank
        if heatmap.class_label() != 'Null':
            X_actual.append(heatmap.heatmap_data().ravel().tolist())
            Y_actual.append(heatmap.class_label())
        
        l = heatmap.class_label()
    labels.append(l)
labels = list( dict.fromkeys(labels)) # remove duplicate labels for non-binary classification
X_train, X_test, Y_train, Y_test = train_test_split(X_actual, Y_actual, random_state=123)

if undersampling:
    # define undersample strategy
    undersample = RandomUnderSampler(sampling_strategy='majority')
    # fit and apply the transform
    X_train, Y_train = undersample.fit_resample(X_train, Y_train)
if oversampling:
    # define undersample strategy
    oversample = RandomOverSampler(sampling_strategy='minority')
    # fit and apply the transform
    X_train, Y_train = oversample.fit_resample(X_train, Y_train)
# ensemble of models
estimator = []
estimator.append(('RF', RandomForestClassifier(
    n_jobs=-1, 
    criterion='gini',
    max_features= 'sqrt',
    n_estimators = 100, 
    oob_score = True)))
#estimator.append(('KNN', KNeighborsClassifier(
#    n_neighbors=5 # we dont talk about this number
#    )))
estimator.append(('ANN', MLPClassifier(
    hidden_layer_sizes=(100,100), 
    activation='relu', 
    solver='adam', 
    max_iter=10000)))
#estimator.append(('NB', GaussianNB()))

if not test_binary:
    print("target:" + target)

# Voting Classifier with soft voting
vot_soft = VotingClassifier(estimators = estimator, voting ='soft')
vot_soft.fit(X_train, Y_train)

print( f"Soft Train score: {vot_soft.score(X_train, Y_train)} " + f"Soft Test score: {vot_soft.score(X_test, Y_test)}")

# Voting Classifier with hard voting
vot_hard = VotingClassifier(estimators = estimator, voting ='hard')
vot_hard.fit(X_train, Y_train)

print( f"RF + ANN Hard Train score: {vot_hard.score(X_train, Y_train)} " + f"RF + ANN Hard Test score: {vot_hard.score(X_test, Y_test)}")

rfc = RandomForestClassifier(n_jobs=-1, criterion='gini', max_features= 'sqrt', n_estimators = 100, oob_score = True) 
rfc.fit(X_train, Y_train)
print( f"RFC Train score: {rfc.score(X_train, Y_train)} " + f"RFC Test score: {rfc.score(X_test, Y_test)}")

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, Y_train)
print( f"KNN Train score: {knn.score(X_train, Y_train)} " + f"KNN Test score: {knn.score(X_test, Y_test)}")

ann = MLPClassifier(hidden_layer_sizes=(100,100), activation='relu',solver='adam', max_iter=10000)
ann.fit(X_train, Y_train)
print( f"ANN Train score: {ann.score(X_train, Y_train)} " + f"ANN Test score: {ann.score(X_test, Y_test)}")

nb = GaussianNB()
nb.fit(X_train, Y_train)
print( f"NB Train score: {nb.score(X_train, Y_train)} " + f"NB Test score: {nb.score(X_test, Y_test)}")

# Plotting
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

if test_binary:
    print("Hard Vote Confusion Matrix:")
    y_rf_predict = vot_hard.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis')
    plt.show()

    print("RF Confusion Matrix:")
    y_rf_predict = rfc.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis')
    plt.show()

    print("KNN Confusion Matrix:")
    y_rf_predict = knn.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis')
    plt.show()

else:

    fig, ax = plt.subplots(6, figsize=(10,50))

    ax[0].set_title("RF + ANN Hard Vote Confusion Matrix:")
    y_rf_predict = vot_hard.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis', xticks_rotation=-45.0, labels=labels, ax=ax[0])

    ax[1].set_title("Soft Vote Confusion Matrix:")
    y_rf_predict = vot_soft.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis', xticks_rotation=-45.0, labels=labels, ax=ax[1])

    ax[2].set_title("RF Confusion Matrix:")
    y_rf_predict = rfc.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis', xticks_rotation=-45.0, labels=labels, ax=ax[2])

    ax[3].set_title("KNN Confusion Matrix:")
    y_rf_predict = knn.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis', xticks_rotation=-45.0, labels=labels, ax=ax[3])

    ax[4].set_title("NB Confusion Matrix:")
    y_rf_predict = nb.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis', xticks_rotation=-45.0, labels=labels, ax=ax[4])

    ax[5].set_title("ANN Confusion Matrix:")
    y_rf_predict = ann.predict(X_test)
    ConfusionMatrixDisplay.from_predictions(Y_test, y_rf_predict, cmap='cividis', xticks_rotation=-45.0, labels=labels, ax=ax[5])
# Out:
# target:MAR
# Soft Train score: 1.0 Soft Test score: 0.875
# RF + ANN Hard Train score: 1.0 RF + ANN Hard Test score: 0.8680555555555556
# RFC Train score: 1.0 RFC Test score: 0.8680555555555556
# KNN Train score: 0.7237569060773481 KNN Test score: 0.5763888888888888
# ANN Train score: 0.9988950276243094 ANN Test score: 0.84375
# NB Train score: 0.594475138121547 NB Test score: 0.6354166666666666

# %%
import numpy as np
import matplotlib.pyplot as plt

# We want to plot the feature importance of all features to see how our classifier is splitting data
importances = rfc.feature_importances_
#indices = np.argsort(importances)

# Expand figure vertically
plt.figure(figsize=(7,20))

# Barplot
plt.barh(range(len(importances)), importances)
# Add feature names as y-axis labels
# replace [indices[i] for i in indices] with feature labels
plt.yticks(range(len(importances)), KeyboardHeatmap.heatmap_data_names())
# Create plot title
plt.title("Feature Importance")
# Show plot
plt.show()

# %%
from sklearn import tree

# Plot one tree in our forest for fun
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=200)
tree.plot_tree(rfc.estimators_[0], fontsize=5,feature_names = KeyboardHeatmap.heatmap_data_names(),filled = True)
# Out:
# [Text(452.0770263671875, 585.125, '2_duration <= 0.08\ngini = 0.802\nsamples = 393\nvalue = [131, 150, 70, 10, 116, 11, 146]'),
#  Text(320.482177734375, 547.375, '4_frequency <= 0.008\ngini = 0.801\nsamples = 346\nvalue = [83, 131, 70, 10, 102, 11, 146]'),
#  Text(315.638427734375, 509.625, 'middle_finger_shortest_duration <= 0.105\ngini = 0.802\nsamples = 320\nvalue = [83, 83, 70, 10, 102, 11, 146]'),
#  Text(160.97900390625, 471.875, 'middle_finger_shortest_duration <= 0.059\ngini = 0.77\nsamples = 165\nvalue = [68, 52, 16, 3, 88, 6, 37]'),
#  Text(67.8125, 434.125, 'q_duration <= 0.035\ngini = 0.748\nsamples = 46\nvalue = [28, 7, 9, 3, 2, 6, 27]'),
#  Text(62.96875, 396.375, 'Key.space_frequency <= 0.042\ngini = 0.73\nsamples = 44\nvalue = [28, 7, 9, 0, 2, 6, 27]'),
#  Text(43.59375, 358.625, 'Mouse.left_duration <= 0.313\ngini = 0.696\nsamples = 29\nvalue = [24, 4, 9, 0, 2, 6, 4]'),
#  Text(38.75, 320.875, 'Key.ctrl_l_frequency <= 0.017\ngini = 0.625\nsamples = 26\nvalue = [24, 4, 9, 0, 2, 0, 4]'),
#  Text(29.0625, 283.125, 'd_frequency <= 0.258\ngini = 0.629\nsamples = 19\nvalue = [16, 0, 9, 0, 2, 0, 4]'),
#  Text(24.21875, 245.375, 'w_duration <= 0.178\ngini = 0.544\nsamples = 15\nvalue = [16, 0, 3, 0, 2, 0, 4]'),
#  Text(19.375, 207.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(29.0625, 207.625, 'Mouse.right_duration <= 0.092\ngini = 0.484\nsamples = 14\nvalue = [16, 0, 3, 0, 2, 0, 2]'),
#  Text(19.375, 169.875, 's_frequency <= 0.025\ngini = 0.219\nsamples = 10\nvalue = [14, 0, 0, 0, 2, 0, 0]'),
#  Text(14.53125, 132.125, 'Key.tab_duration <= 1.772\ngini = 0.375\nsamples = 5\nvalue = [6, 0, 0, 0, 2, 0, 0]'),
#  Text(9.6875, 94.375, 'Key.space_duration <= 0.104\ngini = 0.5\nsamples = 3\nvalue = [2, 0, 0, 0, 2, 0, 0]'),
#  Text(4.84375, 56.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(14.53125, 56.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0, 0]'),
#  Text(19.375, 94.375, 'gini = 0.0\nsamples = 2\nvalue = [4, 0, 0, 0, 0, 0, 0]'),
#  Text(24.21875, 132.125, 'gini = 0.0\nsamples = 5\nvalue = [8, 0, 0, 0, 0, 0, 0]'),
#  Text(38.75, 169.875, 's_frequency <= 0.058\ngini = 0.653\nsamples = 4\nvalue = [2, 0, 3, 0, 0, 0, 2]'),
#  Text(33.90625, 132.125, 'Key.tab_frequency <= 0.042\ngini = 0.5\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 2]'),
#  Text(29.0625, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(38.75, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(43.59375, 132.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0, 0]'),
#  Text(33.90625, 245.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 6, 0, 0, 0, 0]'),
#  Text(48.4375, 283.125, 'd_frequency <= 0.125\ngini = 0.444\nsamples = 7\nvalue = [8, 4, 0, 0, 0, 0, 0]'),
#  Text(43.59375, 245.375, 'gini = 0.0\nsamples = 4\nvalue = [8, 0, 0, 0, 0, 0, 0]'),
#  Text(53.28125, 245.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 4, 0, 0, 0, 0, 0]'),
#  Text(48.4375, 320.875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 6, 0]'),
#  Text(82.34375, 358.625, 'Mouse.left_frequency <= 0.483\ngini = 0.384\nsamples = 15\nvalue = [4, 3, 0, 0, 0, 0, 23]'),
#  Text(72.65625, 320.875, 'b_frequency <= 0.008\ngini = 0.261\nsamples = 13\nvalue = [3, 1, 0, 0, 0, 0, 23]'),
#  Text(67.8125, 283.125, 'Key.space_frequency <= 0.092\ngini = 0.204\nsamples = 12\nvalue = [3, 0, 0, 0, 0, 0, 23]'),
#  Text(62.96875, 245.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 0, 10]'),
#  Text(72.65625, 245.375, 's_duration <= 0.552\ngini = 0.305\nsamples = 8\nvalue = [3, 0, 0, 0, 0, 0, 13]'),
#  Text(67.8125, 207.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 0, 0, 13]'),
#  Text(77.5, 207.625, 'gini = 0.0\nsamples = 2\nvalue = [3, 0, 0, 0, 0, 0, 0]'),
#  Text(77.5, 283.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(92.03125, 320.875, 's_frequency <= 0.042\ngini = 0.444\nsamples = 2\nvalue = [1, 2, 0, 0, 0, 0, 0]'),
#  Text(87.1875, 283.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0, 0]'),
#  Text(96.875, 283.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(72.65625, 396.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0, 0]'),
#  Text(254.1455078125, 434.125, 'w_frequency <= 0.275\ngini = 0.684\nsamples = 119\nvalue = [40, 45, 7, 0, 86, 0, 10]'),
#  Text(207.978515625, 396.375, 'Mouse.right_frequency <= 0.008\ngini = 0.727\nsamples = 84\nvalue = [39, 45, 5, 0, 33, 0, 10]'),
#  Text(161.66015625, 358.625, '2_frequency <= 0.025\ngini = 0.713\nsamples = 62\nvalue = [35, 22, 1, 0, 32, 0, 9]'),
#  Text(156.81640625, 320.875, 's_duration <= 0.628\ngini = 0.714\nsamples = 61\nvalue = [35, 22, 1, 0, 29, 0, 9]'),
#  Text(111.40625, 283.125, 'Key.space_frequency <= 0.075\ngini = 0.611\nsamples = 34\nvalue = [9, 12, 0, 0, 28, 0, 2]'),
#  Text(96.875, 245.375, 'a_duration <= 0.552\ngini = 0.474\nsamples = 19\nvalue = [7, 1, 0, 0, 19, 0, 1]'),
#  Text(87.1875, 207.625, 'w_duration <= 3.946\ngini = 0.177\nsamples = 15\nvalue = [1, 1, 0, 0, 19, 0, 0]'),
#  Text(82.34375, 169.875, 'middle_finger_avg_duration <= 0.161\ngini = 0.095\nsamples = 14\nvalue = [0, 1, 0, 0, 19, 0, 0]'),
#  Text(77.5, 132.125, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 18, 0, 0]'),
#  Text(87.1875, 132.125, 'd_duration <= 0.325\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0, 0]'),
#  Text(82.34375, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(92.03125, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(92.03125, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(106.5625, 207.625, 'd_frequency <= 0.308\ngini = 0.245\nsamples = 4\nvalue = [6, 0, 0, 0, 0, 0, 1]'),
#  Text(101.71875, 169.875, 'gini = 0.0\nsamples = 3\nvalue = [6, 0, 0, 0, 0, 0, 0]'),
#  Text(111.40625, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(125.9375, 245.375, 'Key.space_frequency <= 0.108\ngini = 0.609\nsamples = 15\nvalue = [2, 11, 0, 0, 9, 0, 1]'),
#  Text(121.09375, 207.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 5, 0, 0, 0, 0, 0]'),
#  Text(130.78125, 207.625, 'Key.tab_frequency <= 0.008\ngini = 0.623\nsamples = 11\nvalue = [2, 6, 0, 0, 9, 0, 1]'),
#  Text(121.09375, 169.875, 'w_duration <= 3.474\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 0, 0, 9, 0, 1]'),
#  Text(116.25, 132.125, 'a_duration <= 0.436\ngini = 0.403\nsamples = 7\nvalue = [0, 2, 0, 0, 9, 0, 1]'),
#  Text(111.40625, 94.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 8, 0, 0]'),
#  Text(121.09375, 94.375, 'Mouse.left_frequency <= 0.308\ngini = 0.625\nsamples = 4\nvalue = [0, 2, 0, 0, 1, 0, 1]'),
#  Text(116.25, 56.625, 'middle_finger_shortest_duration <= 0.083\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 0, 1]'),
#  Text(111.40625, 18.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(121.09375, 18.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(125.9375, 56.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0, 0]'),
#  Text(125.9375, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0, 0]'),
#  Text(140.46875, 169.875, 'w_duration <= 2.789\ngini = 0.5\nsamples = 3\nvalue = [2, 2, 0, 0, 0, 0, 0]'),
#  Text(135.625, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(145.3125, 132.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0, 0]'),
#  Text(202.2265625, 283.125, 'a_duration <= 0.784\ngini = 0.592\nsamples = 27\nvalue = [26, 10, 1, 0, 1, 0, 7]'),
#  Text(186.484375, 245.375, 'd_frequency <= 0.225\ngini = 0.696\nsamples = 19\nvalue = [10, 10, 1, 0, 1, 0, 6]'),
#  Text(169.53125, 207.625, 'Key.tab_frequency <= 0.008\ngini = 0.539\nsamples = 11\nvalue = [10, 1, 0, 0, 1, 0, 4]'),
#  Text(159.84375, 169.875, 'w_duration <= 1.615\ngini = 0.571\nsamples = 4\nvalue = [2, 0, 0, 0, 1, 0, 4]'),
#  Text(155.0, 132.125, 'a_frequency <= 0.292\ngini = 0.444\nsamples = 2\nvalue = [2, 0, 0, 0, 1, 0, 0]'),
#  Text(150.15625, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(159.84375, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(164.6875, 132.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 4]'),
#  Text(179.21875, 169.875, 'middle_finger_shortest_duration <= 0.098\ngini = 0.198\nsamples = 7\nvalue = [8, 1, 0, 0, 0, 0, 0]'),
#  Text(174.375, 132.125, 'gini = 0.0\nsamples = 6\nvalue = [8, 0, 0, 0, 0, 0, 0]'),
#  Text(184.0625, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(203.4375, 207.625, 'Key.tab_frequency <= 0.008\ngini = 0.403\nsamples = 8\nvalue = [0, 9, 1, 0, 0, 0, 2]'),
#  Text(198.59375, 169.875, 'd_duration <= 0.565\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 0, 0, 2]'),
#  Text(193.75, 132.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(203.4375, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(208.28125, 169.875, 'gini = 0.0\nsamples = 5\nvalue = [0, 9, 0, 0, 0, 0, 0]'),
#  Text(217.96875, 245.375, 'Key.space_duration <= 0.203\ngini = 0.111\nsamples = 8\nvalue = [16, 0, 0, 0, 0, 0, 1]'),
#  Text(213.125, 207.625, 'gini = 0.0\nsamples = 5\nvalue = [11, 0, 0, 0, 0, 0, 0]'),
#  Text(222.8125, 207.625, 'd_frequency <= 0.233\ngini = 0.278\nsamples = 3\nvalue = [5, 0, 0, 0, 0, 0, 1]'),
#  Text(217.96875, 169.875, 's_frequency <= 0.117\ngini = 0.444\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 1]'),
#  Text(213.125, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(222.8125, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(227.65625, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [3, 0, 0, 0, 0, 0, 0]'),
#  Text(166.50390625, 320.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 3, 0, 0]'),
#  Text(254.296875, 358.625, 'r_duration <= 0.044\ngini = 0.483\nsamples = 22\nvalue = [4, 23, 4, 0, 1, 0, 1]'),
#  Text(242.1875, 320.875, 'a_frequency <= 0.142\ngini = 0.304\nsamples = 18\nvalue = [4, 23, 0, 0, 0, 0, 1]'),
#  Text(232.5, 283.125, 'a_duration <= 0.552\ngini = 0.32\nsamples = 3\nvalue = [4, 1, 0, 0, 0, 0, 0]'),
#  Text(227.65625, 245.375, 'gini = 0.0\nsamples = 2\nvalue = [4, 0, 0, 0, 0, 0, 0]'),
#  Text(237.34375, 245.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(251.875, 283.125, 'Key.tab_frequency <= 0.008\ngini = 0.083\nsamples = 15\nvalue = [0, 22, 0, 0, 0, 0, 1]'),
#  Text(247.03125, 245.375, 'Key.space_duration <= 0.155\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 0, 0, 1]'),
#  Text(242.1875, 207.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0, 0]'),
#  Text(251.875, 207.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(256.71875, 245.375, 'gini = 0.0\nsamples = 12\nvalue = [0, 20, 0, 0, 0, 0, 0]'),
#  Text(266.40625, 320.875, 'Key.space_duration <= 0.073\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 4, 0, 1, 0, 0]'),
#  Text(261.5625, 283.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(271.25, 283.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0, 0, 0]'),
#  Text(300.3125, 396.375, 'Mouse.right_duration <= 0.089\ngini = 0.103\nsamples = 35\nvalue = [1, 0, 2, 0, 53, 0, 0]'),
#  Text(295.46875, 358.625, 'middle_finger_avg_duration <= 0.168\ngini = 0.071\nsamples = 34\nvalue = [1, 0, 1, 0, 53, 0, 0]'),
#  Text(285.78125, 320.875, 'Key.space_duration <= 0.172\ngini = 0.039\nsamples = 31\nvalue = [1, 0, 0, 0, 49, 0, 0]'),
#  Text(280.9375, 283.125, 'Key.tab_duration <= 1.417\ngini = 0.124\nsamples = 11\nvalue = [1, 0, 0, 0, 14, 0, 0]'),
#  Text(276.09375, 245.375, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 14, 0, 0]'),
#  Text(285.78125, 245.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(290.625, 283.125, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 0, 0, 35, 0, 0]'),
#  Text(305.15625, 320.875, 'Mouse.left_frequency <= 0.4\ngini = 0.32\nsamples = 3\nvalue = [0, 0, 1, 0, 4, 0, 0]'),
#  Text(300.3125, 283.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 4, 0, 0]'),
#  Text(310.0, 283.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(305.15625, 358.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(470.2978515625, 471.875, 'Key.space_duration <= 0.155\ngini = 0.706\nsamples = 155\nvalue = [15, 31, 54, 7, 14, 5, 109]'),
#  Text(415.95703125, 434.125, 'a_duration <= 0.49\ngini = 0.787\nsamples = 58\nvalue = [9, 17, 29, 6, 12, 5, 4]'),
#  Text(371.7578125, 396.375, 'd_frequency <= 0.192\ngini = 0.813\nsamples = 40\nvalue = [4, 16, 9, 6, 12, 4, 4]'),
#  Text(336.640625, 358.625, 'd_frequency <= 0.125\ngini = 0.604\nsamples = 11\nvalue = [3, 11, 0, 0, 0, 2, 3]'),
#  Text(324.53125, 320.875, 'w_duration <= 1.847\ngini = 0.5\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 2, 2]'),
#  Text(319.6875, 283.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 2, 0]'),
#  Text(329.375, 283.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(348.75, 320.875, 'middle_finger_longest_duration <= 0.187\ngini = 0.418\nsamples = 8\nvalue = [3, 11, 0, 0, 0, 0, 1]'),
#  Text(339.0625, 283.125, 's_duration <= 0.567\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 0, 1]'),
#  Text(334.21875, 245.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(343.90625, 245.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(358.4375, 283.125, 'Key.ctrl_l_duration <= 0.225\ngini = 0.26\nsamples = 6\nvalue = [2, 11, 0, 0, 0, 0, 0]'),
#  Text(353.59375, 245.375, 'middle_finger_longest_duration <= 0.215\ngini = 0.444\nsamples = 4\nvalue = [2, 4, 0, 0, 0, 0, 0]'),
#  Text(348.75, 207.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(358.4375, 207.625, 'b_frequency <= 0.017\ngini = 0.32\nsamples = 3\nvalue = [1, 4, 0, 0, 0, 0, 0]'),
#  Text(353.59375, 169.875, 'middle_finger_avg_duration <= 0.162\ngini = 0.444\nsamples = 2\nvalue = [1, 2, 0, 0, 0, 0, 0]'),
#  Text(348.75, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0, 0]'),
#  Text(358.4375, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(363.28125, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0, 0]'),
#  Text(363.28125, 245.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 7, 0, 0, 0, 0, 0]'),
#  Text(406.875, 358.625, 'q_frequency <= 0.025\ngini = 0.775\nsamples = 29\nvalue = [1, 5, 9, 6, 12, 2, 1]'),
#  Text(402.03125, 320.875, 'Mouse.left_duration <= 0.613\ngini = 0.716\nsamples = 26\nvalue = [1, 5, 9, 0, 12, 2, 1]'),
#  Text(397.1875, 283.125, 'a_duration <= 0.241\ngini = 0.657\nsamples = 24\nvalue = [1, 1, 9, 0, 12, 2, 1]'),
#  Text(392.34375, 245.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0, 0]'),
#  Text(402.03125, 245.375, 's_duration <= 0.435\ngini = 0.647\nsamples = 21\nvalue = [1, 1, 6, 0, 12, 2, 1]'),
#  Text(382.65625, 207.625, 'middle_finger_avg_duration <= 0.219\ngini = 0.469\nsamples = 13\nvalue = [1, 0, 1, 0, 10, 1, 1]'),
#  Text(372.96875, 169.875, 'middle_finger_avg_duration <= 0.205\ngini = 0.165\nsamples = 10\nvalue = [1, 0, 0, 0, 10, 0, 0]'),
#  Text(368.125, 132.125, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 9, 0, 0]'),
#  Text(377.8125, 132.125, 'w_frequency <= 0.208\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0, 0]'),
#  Text(372.96875, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(382.65625, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(392.34375, 169.875, 'middle_finger_shortest_duration <= 0.179\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 0, 0, 1, 1]'),
#  Text(387.5, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]'),
#  Text(397.1875, 132.125, 'w_frequency <= 0.158\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1, 0]'),
#  Text(392.34375, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(402.03125, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(421.40625, 207.625, 'Mouse.right_frequency <= 0.025\ngini = 0.617\nsamples = 8\nvalue = [0, 1, 5, 0, 2, 1, 0]'),
#  Text(411.71875, 169.875, 's_duration <= 0.733\ngini = 0.444\nsamples = 2\nvalue = [0, 1, 0, 0, 2, 0, 0]'),
#  Text(406.875, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0, 0]'),
#  Text(416.5625, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(431.09375, 169.875, 'middle_finger_shortest_duration <= 0.162\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 0, 0, 1, 0]'),
#  Text(426.25, 132.125, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0, 0]'),
#  Text(435.9375, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(406.875, 283.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0, 0, 0]'),
#  Text(411.71875, 320.875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 6, 0, 0, 0]'),
#  Text(460.15625, 396.375, 'Key.ctrl_l_duration <= 0.244\ngini = 0.414\nsamples = 18\nvalue = [5, 1, 20, 0, 0, 1, 0]'),
#  Text(455.3125, 358.625, 'middle_finger_avg_duration <= 0.267\ngini = 0.382\nsamples = 17\nvalue = [4, 1, 20, 0, 0, 1, 0]'),
#  Text(450.46875, 320.875, 'Mouse.left_frequency <= 0.158\ngini = 0.333\nsamples = 16\nvalue = [4, 0, 20, 0, 0, 1, 0]'),
#  Text(445.625, 283.125, 'Mouse.right_duration <= 0.818\ngini = 0.542\nsamples = 10\nvalue = [4, 0, 7, 0, 0, 1, 0]'),
#  Text(440.78125, 245.375, 'middle_finger_longest_duration <= 0.25\ngini = 0.463\nsamples = 9\nvalue = [4, 0, 7, 0, 0, 0, 0]'),
#  Text(435.9375, 207.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0, 0]'),
#  Text(445.625, 207.625, 'middle_finger_longest_duration <= 0.291\ngini = 0.219\nsamples = 6\nvalue = [1, 0, 7, 0, 0, 0, 0]'),
#  Text(440.78125, 169.875, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 7, 0, 0, 0, 0]'),
#  Text(450.46875, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(450.46875, 245.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]'),
#  Text(455.3125, 283.125, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 13, 0, 0, 0, 0]'),
#  Text(460.15625, 320.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(465.0, 358.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(524.638671875, 434.125, 'middle_finger_longest_duration <= 0.144\ngini = 0.492\nsamples = 97\nvalue = [6, 14, 25, 1, 2, 0, 105]'),
#  Text(502.5390625, 396.375, 'Mouse.right_frequency <= 0.008\ngini = 0.346\nsamples = 4\nvalue = [0, 7, 0, 0, 0, 0, 2]'),
#  Text(497.6953125, 358.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(507.3828125, 358.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 7, 0, 0, 0, 0, 0]'),
#  Text(546.73828125, 396.375, 'Key.space_duration <= 0.296\ngini = 0.454\nsamples = 93\nvalue = [6, 7, 25, 1, 2, 0, 103]'),
#  Text(517.0703125, 358.625, 'Key.space_frequency <= 0.058\ngini = 0.34\nsamples = 83\nvalue = [5, 7, 11, 1, 1, 0, 103]'),
#  Text(489.21875, 320.875, 'Key.space_duration <= 0.202\ngini = 0.704\nsamples = 18\nvalue = [4, 1, 10, 1, 1, 0, 9]'),
#  Text(479.53125, 283.125, 'd_duration <= 0.479\ngini = 0.685\nsamples = 12\nvalue = [4, 1, 8, 0, 1, 0, 3]'),
#  Text(474.6875, 245.375, 'Mouse.left_frequency <= 0.158\ngini = 0.72\nsamples = 8\nvalue = [4, 1, 1, 0, 1, 0, 3]'),
#  Text(465.0, 207.625, 'd_duration <= 0.26\ngini = 0.667\nsamples = 5\nvalue = [1, 1, 0, 0, 1, 0, 3]'),
#  Text(460.15625, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(469.84375, 169.875, 'Mouse.left_duration <= 0.884\ngini = 0.56\nsamples = 4\nvalue = [0, 1, 0, 0, 1, 0, 3]'),
#  Text(465.0, 132.125, 's_duration <= 0.603\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0, 0]'),
#  Text(460.15625, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(469.84375, 94.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(474.6875, 132.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(484.375, 207.625, 'Key.tab_duration <= 0.419\ngini = 0.375\nsamples = 3\nvalue = [3, 0, 1, 0, 0, 0, 0]'),
#  Text(479.53125, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(489.21875, 169.875, 'gini = 0.0\nsamples = 2\nvalue = [3, 0, 0, 0, 0, 0, 0]'),
#  Text(484.375, 245.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7, 0, 0, 0, 0]'),
#  Text(498.90625, 283.125, 'Mouse.left_frequency <= 0.242\ngini = 0.494\nsamples = 6\nvalue = [0, 0, 2, 1, 0, 0, 6]'),
#  Text(494.0625, 245.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 0, 6]'),
#  Text(503.75, 245.375, 'a_duration <= 0.324\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0, 0, 0]'),
#  Text(498.90625, 207.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0, 0]'),
#  Text(508.59375, 207.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]'),
#  Text(544.921875, 320.875, 'd_duration <= 0.833\ngini = 0.147\nsamples = 65\nvalue = [1, 6, 1, 0, 0, 0, 94]'),
#  Text(532.8125, 283.125, 'Key.ctrl_l_frequency <= 0.008\ngini = 0.084\nsamples = 59\nvalue = [1, 2, 1, 0, 0, 0, 88]'),
#  Text(523.125, 245.375, 'd_duration <= 0.553\ngini = 0.066\nsamples = 56\nvalue = [1, 1, 1, 0, 0, 0, 86]'),
#  Text(518.28125, 207.625, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 0, 0, 0, 0, 63]'),
#  Text(527.96875, 207.625, 'Mouse.right_duration <= 0.175\ngini = 0.213\nsamples = 18\nvalue = [1, 1, 1, 0, 0, 0, 23]'),
#  Text(523.125, 169.875, 'Mouse.right_frequency <= 0.208\ngini = 0.15\nsamples = 17\nvalue = [1, 0, 1, 0, 0, 0, 23]'),
#  Text(518.28125, 132.125, 'a_duration <= 0.817\ngini = 0.08\nsamples = 16\nvalue = [1, 0, 0, 0, 0, 0, 23]'),
#  Text(513.4375, 94.375, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 0, 0, 20]'),
#  Text(523.125, 94.375, 'Mouse.left_frequency <= 0.083\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 0, 0, 0, 3]'),
#  Text(518.28125, 56.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(527.96875, 56.625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]'),
#  Text(527.96875, 132.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]'),
#  Text(532.8125, 169.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(542.5, 245.375, 'd_duration <= 0.394\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 0, 0, 2]'),
#  Text(537.65625, 207.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]'),
#  Text(547.34375, 207.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(557.03125, 283.125, 'Key.tab_frequency <= 0.008\ngini = 0.48\nsamples = 6\nvalue = [0, 4, 0, 0, 0, 0, 6]'),
#  Text(552.1875, 245.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 0, 0, 6]'),
#  Text(561.875, 245.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0, 0, 0]'),
#  Text(576.40625, 358.625, 'middle_finger_avg_duration <= 0.149\ngini = 0.227\nsamples = 10\nvalue = [1, 0, 14, 0, 1, 0, 0]'),
#  Text(571.5625, 320.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(581.25, 320.875, 'Key.space_duration <= 0.755\ngini = 0.124\nsamples = 9\nvalue = [1, 0, 14, 0, 0, 0, 0]'),
#  Text(576.40625, 283.125, 'Key.tab_duration <= 5.485\ngini = 0.278\nsamples = 4\nvalue = [1, 0, 5, 0, 0, 0, 0]'),
#  Text(571.5625, 245.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 5, 0, 0, 0, 0]'),
#  Text(581.25, 245.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(586.09375, 283.125, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 9, 0, 0, 0, 0]'),
#  Text(325.325927734375, 509.625, 'gini = 0.0\nsamples = 26\nvalue = [0, 48, 0, 0, 0, 0, 0]'),
#  Text(583.671875, 547.375, 'a_frequency <= 0.258\ngini = 0.564\nsamples = 47\nvalue = [48, 19, 0, 0, 14, 0, 0]'),
#  Text(566.71875, 509.625, 'r_frequency <= 0.017\ngini = 0.32\nsamples = 29\nvalue = [40, 10, 0, 0, 0, 0, 0]'),
#  Text(561.875, 471.875, 'Mouse.left_duration <= 0.141\ngini = 0.3\nsamples = 28\nvalue = [40, 9, 0, 0, 0, 0, 0]'),
#  Text(557.03125, 434.125, 'gini = 0.0\nsamples = 23\nvalue = [39, 0, 0, 0, 0, 0, 0]'),
#  Text(566.71875, 434.125, 'Key.space_duration <= 0.076\ngini = 0.18\nsamples = 5\nvalue = [1, 9, 0, 0, 0, 0, 0]'),
#  Text(561.875, 396.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]'),
#  Text(571.5625, 396.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 9, 0, 0, 0, 0, 0]'),
#  Text(571.5625, 471.875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]'),
#  Text(600.625, 509.625, 'd_frequency <= 0.258\ngini = 0.645\nsamples = 18\nvalue = [8, 9, 0, 0, 14, 0, 0]'),
#  Text(590.9375, 471.875, 'Mouse.left_frequency <= 0.4\ngini = 0.521\nsamples = 8\nvalue = [8, 4, 0, 0, 1, 0, 0]'),
#  Text(586.09375, 434.125, 'Key.space_duration <= 0.218\ngini = 0.571\nsamples = 4\nvalue = [2, 4, 0, 0, 1, 0, 0]'),
#  Text(581.25, 396.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0, 0, 0]'),
#  Text(590.9375, 396.375, 'a_duration <= 0.513\ngini = 0.444\nsamples = 2\nvalue = [2, 0, 0, 0, 1, 0, 0]'),
#  Text(586.09375, 358.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]'),
#  Text(595.78125, 358.625, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0, 0, 0, 0, 0]'),
#  Text(595.78125, 434.125, 'gini = 0.0\nsamples = 4\nvalue = [6, 0, 0, 0, 0, 0, 0]'),
#  Text(610.3125, 471.875, 'Mouse.right_duration <= 0.104\ngini = 0.401\nsamples = 10\nvalue = [0, 5, 0, 0, 13, 0, 0]'),
#  Text(605.46875, 434.125, 'w_duration <= 1.64\ngini = 0.305\nsamples = 9\nvalue = [0, 3, 0, 0, 13, 0, 0]'),
#  Text(600.625, 396.375, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 13, 0, 0]'),
#  Text(610.3125, 396.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0, 0, 0, 0, 0]'),
#  Text(615.15625, 434.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0, 0]')]
